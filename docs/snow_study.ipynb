# %% [markdown]
# # Design Case: Snow Study
#
# Paul T. Grogan <paul.grogan@asu.edu>

# %% [markdown]
# What is the observable region from the following satellites/sensors integrated at 1-day intervals for an entire calendar year?
#
#  * Advanced Microwave Scanning Radiometer 2 (AMSR2)
#    * 1450 km swath width
#    * Onboard Global Change Observation Mission for Water (GCOM-W)
#    * Only consider descending (morning) orbits
#  * Synthetic Aperture Radar C-Band (SAR-C)
#    * 250 km swath width
#    * Onboard Sentinel-1A
#  * Synthetic Aperture Radar L-Band (SAR-L)
#  Sentinel-1A
#    * 252 km swath width
#    * Onboard NASA-ISRO Sythetic Aperture Radar (NISAR)
#  * Advanced Topographic Laser Altimeter System (ATLAS)
#    * 6.6 km effective swath width
#    * Onboard Ice, Cloud, and Land Elevation Satellite (ICESat-2)
